# %% [markdown]
# # Regression

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("Dataset/house-price/housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data = pd.get_dummies(data, columns=['ocean_proximity'], drop_first=True,dtype=int)

# %%
y = data['median_house_value']
X = data.drop(["median_house_value"],axis=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,test_size=0.2)

# %%
sc =  StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
X_val = sc.transform(X_val)

# %% [markdown]
# ##  Sub-Class API
# <hr>

# %%
class WideAndDeepANN (keras.Model):
    def __init__(self,activation="relu",**kwargs):
        super().__init__(**kwargs)
        self.hidden_layer1 = keras.layers.Dense(50,activation=activation)
        self.hidden_layer2 = keras.layers.Dense(10,activation=activation)
        self.final_output = keras.layers.Dense(1)
        self.helper_output = keras.layers.Dense(1)

    def call(self,inputs):
        input_1,input_2 = inputs
        h1_out = self.hidden_layer1(input_1)
        h2_out = self.hidden_layer2(h1_out)
        concat_out = keras.layers.concatenate([input_2,h2_out])
        final_output  = self.final_output(concat_out)
        helper_output  = self.helper_output(h2_out)
        return final_output,helper_output

# %%
model = WideAndDeepANN()

# %%
model.compile(loss=["mse","mae"],
              loss_weights = [0.8,0.2],
              optimizer="sgd",
              metrics=[['mean_absolute_error'], ['mean_absolute_error']] 
              )

# %%
model.fit( (X_train_in_1,X_train_in_2) , (y_train,y_train) ,epochs=40 , validation_data=( (X_val_in_1,X_val_in_2) ,(y_val,y_val)))
# Out:
# Epoch 1/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 5901388680790016.0000 - mae_loss: 207532.3594 - mean_absolute_error: 7935941.0000 - mean_absolute_error_1: 207496.5312 - mse_loss: 7372828370272256.0000 - val_loss: 14590353408.0000 - val_mae_loss: 205463.5312 - val_mean_absolute_error: 103862.6875 - val_mean_absolute_error_1: 205747.3281 - val_mse_loss: 18146291712.0000
# Epoch 2/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8987464704.0000 - mae_loss: 206965.1094 - mean_absolute_error: 80116.0859 - mean_absolute_error_1: 206953.3594 - mse_loss: 11233928192.0000 - val_loss: 8061785600.0000 - val_mae_loss: 205462.5938 - val_mean_absolute_error: 76321.3906 - val_mean_absolute_error_1: 205746.3750 - val_mse_loss: 10052683776.0000
# Epoch 3/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8161473536.0000 - mae_loss: 206935.8281 - mean_absolute_error: 76928.3047 - mean_absolute_error_1: 206952.5625 - mse_loss: 10198798336.0000 - val_loss: 8051815936.0000 - val_mae_loss: 205461.8281 - val_mean_absolute_error: 76904.2734 - val_mean_absolute_error_1: 205745.6250 - val_mse_loss: 10040564736.0000
# Epoch 4/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8171637760.0000 - mae_loss: 206967.4844 - mean_absolute_error: 77213.7109 - mean_absolute_error_1: 206951.6094 - mse_loss: 10218318848.0000 - val_loss: 8059707904.0000 - val_mae_loss: 205460.9062 - val_mean_absolute_error: 76097.8906 - val_mean_absolute_error_1: 205744.6875 - val_mse_loss: 10043339776.0000
# Epoch 5/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8181074944.0000 - mae_loss: 206960.5781 - mean_absolute_error: 77062.8516 - mean_absolute_error_1: 206950.8750 - mse_loss: 10227899392.0000 - val_loss: 8057150464.0000 - val_mae_loss: 205460.1562 - val_mean_absolute_error: 76241.6094 - val_mean_absolute_error_1: 205743.9219 - val_mse_loss: 10040371200.0000
# Epoch 6/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8173386752.0000 - mae_loss: 206956.5312 - mean_absolute_error: 76980.0547 - mean_absolute_error_1: 206950.0625 - mse_loss: 10215272448.0000 - val_loss: 8046031360.0000 - val_mae_loss: 205459.3438 - val_mean_absolute_error: 76830.1484 - val_mean_absolute_error_1: 205743.1250 - val_mse_loss: 10031271936.0000
# Epoch 7/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8187417088.0000 - mae_loss: 206962.9062 - mean_absolute_error: 77103.2031 - mean_absolute_error_1: 206949.1875 - mse_loss: 10236762112.0000 - val_loss: 8058066432.0000 - val_mae_loss: 205458.4688 - val_mean_absolute_error: 76867.4922 - val_mean_absolute_error_1: 205742.2344 - val_mse_loss: 10050596864.0000
# Epoch 8/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8169217536.0000 - mae_loss: 206979.0938 - mean_absolute_error: 77089.6172 - mean_absolute_error_1: 206948.4531 - mse_loss: 10214061056.0000 - val_loss: 8051960320.0000 - val_mae_loss: 205457.7500 - val_mean_absolute_error: 76748.5781 - val_mean_absolute_error_1: 205741.5312 - val_mse_loss: 10037696512.0000
# Epoch 9/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8166520320.0000 - mae_loss: 206946.0938 - mean_absolute_error: 77090.3672 - mean_absolute_error_1: 206947.5781 - mse_loss: 10211573760.0000 - val_loss: 8057946112.0000 - val_mae_loss: 205456.8281 - val_mean_absolute_error: 76591.8203 - val_mean_absolute_error_1: 205740.6094 - val_mse_loss: 10043860992.0000
# Epoch 10/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8166417920.0000 - mae_loss: 206964.2031 - mean_absolute_error: 77084.6172 - mean_absolute_error_1: 206946.7969 - mse_loss: 10209958912.0000 - val_loss: 8049498624.0000 - val_mae_loss: 205456.0625 - val_mean_absolute_error: 76533.2422 - val_mean_absolute_error_1: 205739.8281 - val_mse_loss: 10034698240.0000
# Epoch 11/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8166416384.0000 - mae_loss: 206936.5469 - mean_absolute_error: 77108.9922 - mean_absolute_error_1: 206946.1094 - mse_loss: 10207369216.0000 - val_loss: 8060539904.0000 - val_mae_loss: 205455.1719 - val_mean_absolute_error: 76301.3516 - val_mean_absolute_error_1: 205738.9531 - val_mse_loss: 10046550016.0000
# Epoch 12/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8172673024.0000 - mae_loss: 206950.0469 - mean_absolute_error: 77043.6641 - mean_absolute_error_1: 206945.1406 - mse_loss: 10212973568.0000 - val_loss: 8052511232.0000 - val_mae_loss: 205454.3906 - val_mean_absolute_error: 76499.0547 - val_mean_absolute_error_1: 205738.1562 - val_mse_loss: 10038815744.0000
# Epoch 13/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8176375808.0000 - mae_loss: 206956.7188 - mean_absolute_error: 77013.1016 - mean_absolute_error_1: 206944.3594 - mse_loss: 10222899200.0000 - val_loss: 8057533952.0000 - val_mae_loss: 205453.5781 - val_mean_absolute_error: 76922.4219 - val_mean_absolute_error_1: 205737.3750 - val_mse_loss: 10047491072.0000
# Epoch 14/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8165399552.0000 - mae_loss: 206939.0625 - mean_absolute_error: 77109.6797 - mean_absolute_error_1: 206943.4688 - mse_loss: 10204883968.0000 - val_loss: 8050080256.0000 - val_mae_loss: 205452.6719 - val_mean_absolute_error: 76608.1953 - val_mean_absolute_error_1: 205736.4531 - val_mse_loss: 10037361664.0000
# Epoch 15/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8173804544.0000 - mae_loss: 206930.9219 - mean_absolute_error: 77111.7109 - mean_absolute_error_1: 206942.6406 - mse_loss: 10218673152.0000 - val_loss: 8045446656.0000 - val_mae_loss: 205451.9375 - val_mean_absolute_error: 76451.3594 - val_mean_absolute_error_1: 205735.7188 - val_mse_loss: 10030614528.0000
# Epoch 16/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8167663616.0000 - mae_loss: 206939.4062 - mean_absolute_error: 77022.3516 - mean_absolute_error_1: 206941.7500 - mse_loss: 10207911936.0000 - val_loss: 8049495552.0000 - val_mae_loss: 205451.0312 - val_mean_absolute_error: 76692.9453 - val_mean_absolute_error_1: 205734.8125 - val_mse_loss: 10033777664.0000
# Epoch 17/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8167067136.0000 - mae_loss: 206957.2344 - mean_absolute_error: 77012.3906 - mean_absolute_error_1: 206940.9375 - mse_loss: 10212135936.0000 - val_loss: 8046430208.0000 - val_mae_loss: 205450.2344 - val_mean_absolute_error: 76958.3594 - val_mean_absolute_error_1: 205734.0000 - val_mse_loss: 10031416320.0000
# Epoch 18/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8165322240.0000 - mae_loss: 206971.6406 - mean_absolute_error: 77071.3203 - mean_absolute_error_1: 206940.1719 - mse_loss: 10210219008.0000 - val_loss: 8056510464.0000 - val_mae_loss: 205449.4688 - val_mean_absolute_error: 76993.7578 - val_mean_absolute_error_1: 205733.2344 - val_mse_loss: 10045803520.0000
# Epoch 19/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8165613056.0000 - mae_loss: 206939.7344 - mean_absolute_error: 77084.0859 - mean_absolute_error_1: 206939.3594 - mse_loss: 10203649024.0000 - val_loss: 8048147968.0000 - val_mae_loss: 205448.5312 - val_mean_absolute_error: 76678.1641 - val_mean_absolute_error_1: 205732.3125 - val_mse_loss: 10035225600.0000
# Epoch 20/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8166489088.0000 - mae_loss: 206949.6406 - mean_absolute_error: 77006.5781 - mean_absolute_error_1: 206938.5469 - mse_loss: 10211253248.0000 - val_loss: 8052021248.0000 - val_mae_loss: 205447.7656 - val_mean_absolute_error: 76948.9688 - val_mean_absolute_error_1: 205731.5625 - val_mse_loss: 10040556544.0000
# Epoch 21/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8165241344.0000 - mae_loss: 206959.5156 - mean_absolute_error: 77145.0391 - mean_absolute_error_1: 206937.6719 - mse_loss: 10209782784.0000 - val_loss: 8046662144.0000 - val_mae_loss: 205446.9062 - val_mean_absolute_error: 76432.4062 - val_mean_absolute_error_1: 205730.6875 - val_mse_loss: 10031892480.0000
# Epoch 22/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8161630208.0000 - mae_loss: 206925.0312 - mean_absolute_error: 77071.1328 - mean_absolute_error_1: 206936.9062 - mse_loss: 10200448000.0000 - val_loss: 8052703232.0000 - val_mae_loss: 205446.0781 - val_mean_absolute_error: 76257.7656 - val_mean_absolute_error_1: 205729.8438 - val_mse_loss: 10040950784.0000
# Epoch 23/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8167391744.0000 - mae_loss: 206915.9688 - mean_absolute_error: 77035.0859 - mean_absolute_error_1: 206936.0625 - mse_loss: 10206393344.0000 - val_loss: 8050894848.0000 - val_mae_loss: 205445.3281 - val_mean_absolute_error: 76270.3906 - val_mean_absolute_error_1: 205729.1094 - val_mse_loss: 10033342464.0000
# Epoch 24/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8167781888.0000 - mae_loss: 206957.3125 - mean_absolute_error: 77001.7734 - mean_absolute_error_1: 206935.0781 - mse_loss: 10212061184.0000 - val_loss: 8045198848.0000 - val_mae_loss: 205444.4688 - val_mean_absolute_error: 76693.8359 - val_mean_absolute_error_1: 205728.2500 - val_mse_loss: 10028572672.0000
# Epoch 25/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8166506496.0000 - mae_loss: 206909.4844 - mean_absolute_error: 77046.4062 - mean_absolute_error_1: 206934.4219 - mse_loss: 10206265344.0000 - val_loss: 8051692032.0000 - val_mae_loss: 205443.6719 - val_mean_absolute_error: 76702.5781 - val_mean_absolute_error_1: 205727.4688 - val_mse_loss: 10038145024.0000
# Epoch 26/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8175022080.0000 - mae_loss: 206960.9531 - mean_absolute_error: 77118.0391 - mean_absolute_error_1: 206933.5625 - mse_loss: 10219521024.0000 - val_loss: 8047298560.0000 - val_mae_loss: 205442.7656 - val_mean_absolute_error: 76656.0938 - val_mean_absolute_error_1: 205726.5625 - val_mse_loss: 10034502656.0000
# Epoch 27/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8168646144.0000 - mae_loss: 206931.1250 - mean_absolute_error: 77044.5000 - mean_absolute_error_1: 206932.6719 - mse_loss: 10209994752.0000 - val_loss: 8050715648.0000 - val_mae_loss: 205441.9688 - val_mean_absolute_error: 76721.8438 - val_mean_absolute_error_1: 205725.7188 - val_mse_loss: 10034130944.0000
# Epoch 28/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8187078656.0000 - mae_loss: 206930.5625 - mean_absolute_error: 77165.8438 - mean_absolute_error_1: 206931.9062 - mse_loss: 10233822208.0000 - val_loss: 8053362688.0000 - val_mae_loss: 205441.1406 - val_mean_absolute_error: 76400.8828 - val_mean_absolute_error_1: 205724.9062 - val_mse_loss: 10040717312.0000
# Epoch 29/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8166282752.0000 - mae_loss: 206915.2188 - mean_absolute_error: 77031.6328 - mean_absolute_error_1: 206931.1875 - mse_loss: 10209392640.0000 - val_loss: 8046278144.0000 - val_mae_loss: 205440.3281 - val_mean_absolute_error: 76534.7734 - val_mean_absolute_error_1: 205724.0938 - val_mse_loss: 10028317696.0000
# Epoch 30/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8159539200.0000 - mae_loss: 206959.7344 - mean_absolute_error: 77061.6484 - mean_absolute_error_1: 206930.2500 - mse_loss: 10201843712.0000 - val_loss: 8051035136.0000 - val_mae_loss: 205439.5625 - val_mean_absolute_error: 76454.5938 - val_mean_absolute_error_1: 205723.3438 - val_mse_loss: 10038851584.0000
# Epoch 31/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8164908544.0000 - mae_loss: 206928.2188 - mean_absolute_error: 76980.5938 - mean_absolute_error_1: 206929.4219 - mse_loss: 10206480384.0000 - val_loss: 8052550144.0000 - val_mae_loss: 205438.6719 - val_mean_absolute_error: 76921.2969 - val_mean_absolute_error_1: 205722.4531 - val_mse_loss: 10042451968.0000
# Epoch 32/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8171629568.0000 - mae_loss: 206928.7344 - mean_absolute_error: 77175.6250 - mean_absolute_error_1: 206928.7031 - mse_loss: 10213912576.0000 - val_loss: 8048096256.0000 - val_mae_loss: 205437.8906 - val_mean_absolute_error: 76179.9297 - val_mean_absolute_error_1: 205721.6719 - val_mse_loss: 10032580608.0000
# Epoch 33/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8169090560.0000 - mae_loss: 206940.3125 - mean_absolute_error: 77019.1016 - mean_absolute_error_1: 206927.7656 - mse_loss: 10211186688.0000 - val_loss: 8048565248.0000 - val_mae_loss: 205437.0312 - val_mean_absolute_error: 76542.0781 - val_mean_absolute_error_1: 205720.8281 - val_mse_loss: 10032728064.0000
# Epoch 34/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8163943936.0000 - mae_loss: 206938.7656 - mean_absolute_error: 77115.1484 - mean_absolute_error_1: 206927.0469 - mse_loss: 10205984768.0000 - val_loss: 8061393920.0000 - val_mae_loss: 205436.1875 - val_mean_absolute_error: 76209.5469 - val_mean_absolute_error_1: 205719.9688 - val_mse_loss: 10053187584.0000
# Epoch 35/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8171669504.0000 - mae_loss: 206927.7812 - mean_absolute_error: 76995.6641 - mean_absolute_error_1: 206926.1562 - mse_loss: 10213922816.0000 - val_loss: 8062496768.0000 - val_mae_loss: 205435.4219 - val_mean_absolute_error: 76617.3750 - val_mean_absolute_error_1: 205719.2188 - val_mse_loss: 10052147200.0000
# Epoch 36/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8173739008.0000 - mae_loss: 206938.3594 - mean_absolute_error: 77119.6562 - mean_absolute_error_1: 206925.2656 - mse_loss: 10217458688.0000 - val_loss: 8053497856.0000 - val_mae_loss: 205434.4844 - val_mean_absolute_error: 76460.5000 - val_mean_absolute_error_1: 205718.2656 - val_mse_loss: 10042628096.0000
# Epoch 37/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8167146496.0000 - mae_loss: 206936.5156 - mean_absolute_error: 77008.0078 - mean_absolute_error_1: 206924.5781 - mse_loss: 10210603008.0000 - val_loss: 8048641536.0000 - val_mae_loss: 205433.7500 - val_mean_absolute_error: 76814.9844 - val_mean_absolute_error_1: 205717.5469 - val_mse_loss: 10031834112.0000
# Epoch 38/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8175500800.0000 - mae_loss: 206929.2969 - mean_absolute_error: 77116.9844 - mean_absolute_error_1: 206923.6875 - mse_loss: 10220341248.0000 - val_loss: 8049473024.0000 - val_mae_loss: 205432.8438 - val_mean_absolute_error: 76669.9688 - val_mean_absolute_error_1: 205716.6094 - val_mse_loss: 10037617664.0000
# Epoch 39/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8171847168.0000 - mae_loss: 206920.7344 - mean_absolute_error: 77079.4375 - mean_absolute_error_1: 206922.8438 - mse_loss: 10215894016.0000 - val_loss: 8048992768.0000 - val_mae_loss: 205432.0625 - val_mean_absolute_error: 76615.6562 - val_mean_absolute_error_1: 205715.8281 - val_mse_loss: 10031096832.0000
# Epoch 40/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8166208000.0000 - mae_loss: 206932.2031 - mean_absolute_error: 77084.5781 - mean_absolute_error_1: 206922.0156 - mse_loss: 10209239040.0000 - val_loss: 8046799360.0000 - val_mae_loss: 205431.2500 - val_mean_absolute_error: 76406.9141 - val_mean_absolute_error_1: 205715.0312 - val_mse_loss: 10033273856.0000
