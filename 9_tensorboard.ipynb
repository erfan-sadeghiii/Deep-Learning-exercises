# %% [markdown]
# # Regression

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("Dataset/house-price/housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data = pd.get_dummies(data, columns=['ocean_proximity'], drop_first=True,dtype=int)

# %%
y = data['median_house_value']
X = data.drop(["median_house_value"],axis=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,test_size=0.2)

# %%
sc =  StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
X_val = sc.transform(X_val)

# %%
model_a =  keras.models.Sequential([
    keras.layers.Dense(50,activation="relu"),
    keras.layers.Dense(10,activation="relu"),
    keras.layers.Dense(1)
])

# %%
model_a.compile(loss="mean_squared_error",
              optimizer="sgd",
              metrics=["mean_absolute_error"]
              )

# %%
# model_a.fit(X_train,y_train,epochs=40,validation_data=(X_val,y_val))

# %%
# model_a.evaluate(X_test,y_test)

# %% [markdown]
# ## Functional API
# <hr>

# %%
input_  = keras.layers.Input(shape= X_train.shape[1:])
hidden_layer1 = keras.layers.Dense(50,activation="relu")(input_)
hidden_layer2 = keras.layers.Dense(10,activation="relu")(hidden_layer1)
concatenate_layer = keras.layers.Concatenate()([input_,hidden_layer2])
output = keras.layers.Dense(1)(concatenate_layer)
model_b = keras.Model(inputs=[input_],outputs=[output])

# %%
model_b.compile(loss="mean_squared_error",
              optimizer="sgd",
              metrics=["mean_absolute_error"]
              )

# %%
# model_b.fit(X_train,y_train,epochs=40,validation_data=(X_val,y_val))

# %%
# model_b.evaluate(X_test,y_test)

# %% [markdown]
# ## Multi-input
# <hr>

# %%
X_train_in_1 , X_train_in_2 = X_train[:,:6],X_train[:,-4:]
X_val_in_1 , X_val_in_2 = X_val[:,:6],X_val[:,-4:]
X_test_in_1 , X_test_in_2 = X_test[:,:6],X_test[:,-4:]

# %%
input_1  = keras.layers.Input(shape=[6])
input_2  = keras.layers.Input(shape=[4])
hidden_layer1 = keras.layers.Dense(50,activation="relu")(input_1)
hidden_layer2 = keras.layers.Dense(10,activation="relu")(hidden_layer1)
concatenate_layer = keras.layers.Concatenate()([input_2,hidden_layer2])
output = keras.layers.Dense(1)(concatenate_layer)
model_c = keras.Model(inputs=[input_1,input_2],outputs=[output])

# %%
model_c.compile(loss="mean_squared_error",
              optimizer="sgd",
              metrics=["mean_absolute_error"]
              )

# %%
# model_c.fit( (X_train_in_1,X_train_in_2) , y_train ,epochs=40 , validation_data=( (X_val_in_1,X_val_in_2) ,y_val))

# %% [markdown]
# ## Multi-output
# <hr>

# %%
input_1  = keras.layers.Input(shape=[6])
input_2  = keras.layers.Input(shape=[4])
hidden_layer1 = keras.layers.Dense(50,activation="relu")(input_1)
hidden_layer2 = keras.layers.Dense(10,activation="relu")(hidden_layer1)
concatenate_layer = keras.layers.Concatenate()([input_2,hidden_layer2])
output = keras.layers.Dense(1,name="output")(concatenate_layer)
helper_output = keras.layers.Dense(1,name="helper-output")(hidden_layer2)



model_d = keras.Model(inputs=[input_1,input_2],outputs=[output,helper_output])

# %%
model_d.compile(loss=["mse","mae"],
              loss_weights = [0.8,0.2],
              optimizer="sgd",
              metrics=[['mean_absolute_error'], ['mean_absolute_error']] 
              )

# %%
model_d.fit( (X_train_in_1,X_train_in_2) , (y_train,y_train) ,epochs=40 , validation_data=( (X_val_in_1,X_val_in_2) ,(y_val,y_val)))
# Out:
# Epoch 1/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - helper-output_loss: 207298.3125 - helper-output_mean_absolute_error: 207296.2812 - loss: 8208158720.0000 - output_loss: 10259539968.0000 - output_mean_absolute_error: 77395.4219 - val_helper-output_loss: 207183.0000 - val_helper-output_mean_absolute_error: 205893.2500 - val_loss: 8010409472.0000 - val_output_loss: 10092339200.0000 - val_output_mean_absolute_error: 76018.3359
# Epoch 37/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - helper-output_loss: 207293.7656 - helper-output_mean_absolute_error: 207295.5000 - loss: 8210544640.0000 - output_loss: 10260871168.0000 - output_mean_absolute_error: 77405.1562 - val_helper-output_loss: 207182.1719 - val_helper-output_mean_absolute_error: 205892.4219 - val_loss: 8015254528.0000 - val_output_loss: 10094012416.0000 - val_output_mean_absolute_error: 76060.2578
# Epoch 38/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - helper-output_loss: 207272.7344 - helper-output_mean_absolute_error: 207294.5469 - loss: 8217047040.0000 - output_loss: 10268399616.0000 - output_mean_absolute_error: 77394.2266 - val_helper-output_loss: 207181.3438 - val_helper-output_mean_absolute_error: 205891.5781 - val_loss: 8017047552.0000 - val_output_loss: 10094542848.0000 - val_output_mean_absolute_error: 76069.3594
# Epoch 39/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - helper-output_loss: 207286.1250 - helper-output_mean_absolute_error: 207293.6406 - loss: 8202002432.0000 - output_loss: 10250582016.0000 - output_mean_absolute_error: 77333.3906 - val_helper-output_loss: 207180.5312 - val_helper-output_mean_absolute_error: 205890.7969 - val_loss: 8007791616.0000 - val_output_loss: 10078069760.0000 - val_output_mean_absolute_error: 76309.3203
# Epoch 40/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - helper-output_loss: 207299.9531 - helper-output_mean_absolute_error: 207292.8906 - loss: 8201068544.0000 - output_loss: 10252683264.0000 - output_mean_absolute_error: 77422.6406 - val_helper-output_loss: 207179.7188 - val_helper-output_mean_absolute_error: 205889.9531 - val_loss: 8007073792.0000 - val_output_loss: 10084857856.0000 - val_output_mean_absolute_error: 76020.7891

# %% [markdown]
# ##  Sub-Class API
# <hr>

# %%
class WideAndDeepANN (keras.Model):
    def __init__(self,activation="relu",**kwargs):
        super().__init__(**kwargs)
        self.hidden_layer1 = keras.layers.Dense(50,activation=activation)
        self.hidden_layer2 = keras.layers.Dense(10,activation=activation)
        self.final_output = keras.layers.Dense(1)
        self.helper_output = keras.layers.Dense(1)

    def call(self,inputs):
        input_1,input_2 = inputs
        h1_out = self.hidden_layer1(input_1)
        h2_out = self.hidden_layer2(h1_out)
        concat_out = keras.layers.concatenate([input_2,h2_out])
        final_output  = self.final_output(concat_out)
        helper_output  = self.helper_output(h2_out)
        return final_output,helper_output

# %%
model_f = WideAndDeepANN()

# %%
model_f.compile(loss=["mse","mae"],
              loss_weights = [0.8,0.2],
              optimizer="sgd",
              metrics=[['mean_absolute_error'], ['mean_absolute_error']] 
              )

# %%
# model_f.fit( (X_train_in_1,X_train_in_2) , (y_train,y_train) ,epochs=40 , validation_data=( (X_val_in_1,X_val_in_2) ,(y_val,y_val)))

# %% [markdown]
# ## Saving the model
# <hr>

# %%
# model_d.save("models/model_d.h5")

# %%
# model_d_load = keras.models.load_model("models/model_d.h5", compile=False)

# %% [markdown]
# ## Call-Back API
# <hr>

# %%
model_checkpoint_cb = keras.callbacks.ModelCheckpoint("models/model_reg_cb_best_epoch.h5",save_best_only=True)


early_stop_cb = keras.callbacks.EarlyStopping(patience=5,restore_best_weights=True)

# %% [markdown]
# Costume Callback

# %%
class MyCallback(keras.callbacks.Callback):
    def on_train_end (self,logs=None):
        print("")
    def on_epoch_end(self,epoch,logs):
        print(logs["val_loss"])

# %%
mycb = MyCallback()

# %%
# model_d.fit( (X_train_in_1,X_train_in_2) ,
#              (y_train,y_train) , 
#              epochs=5 ,
#              validation_data=( (X_val_in_1,X_val_in_2) ,(y_val,y_val)),
#              callbacks=[model_checkpoint_cb , early_stop_cb]
             
#              )

# %% [markdown]
# ## Tensorboard
# <hr>

# %%
tb_callback  = keras.callbacks.TensorBoard("log-boards/tb-test")

# %%
model_d.fit( (X_train_in_1,X_train_in_2) ,
             (y_train,y_train) , 
             epochs=5 ,
             validation_data=( (X_val_in_1,X_val_in_2) ,(y_val,y_val)),
             callbacks=[tb_callback]
             
             )
# Out:
# Epoch 1/5
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - helper-output_loss: 207290.4844 - helper-output_mean_absolute_error: 207292.0781 - loss: 8202651136.0000 - output_loss: 10252203008.0000 - output_mean_absolute_error: 77376.9531 - val_helper-output_loss: 207178.8594 - val_helper-output_mean_absolute_error: 205889.1250 - val_loss: 8023430656.0000 - val_output_loss: 10112362496.0000 - val_output_mean_absolute_error: 76132.1250
# Epoch 2/5
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - helper-output_loss: 207299.0156 - helper-output_mean_absolute_error: 207291.3125 - loss: 8199766016.0000 - output_loss: 10252789760.0000 - output_mean_absolute_error: 77429.0547 - val_helper-output_loss: 207178.0781 - val_helper-output_mean_absolute_error: 205888.3281 - val_loss: 8005997056.0000 - val_output_loss: 10080974848.0000 - val_output_mean_absolute_error: 75834.8828
# Epoch 3/5
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - helper-output_loss: 207304.1094 - helper-output_mean_absolute_error: 207290.5000 - loss: 8210187264.0000 - output_loss: 10264609792.0000 - output_mean_absolute_error: 77384.2188 - val_helper-output_loss: 207177.2188 - val_helper-output_mean_absolute_error: 205887.4844 - val_loss: 8017560064.0000 - val_output_loss: 10103745536.0000 - val_output_mean_absolute_error: 76148.4844
# Epoch 4/5
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - helper-output_loss: 207295.1719 - helper-output_mean_absolute_error: 207289.7188 - loss: 8209444864.0000 - output_loss: 10263360512.0000 - output_mean_absolute_error: 77362.7344 - val_helper-output_loss: 207176.3906 - val_helper-output_mean_absolute_error: 205886.6406 - val_loss: 8010273792.0000 - val_output_loss: 10088848384.0000 - val_output_mean_absolute_error: 76290.9688
# Epoch 5/5
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - helper-output_loss: 207290.5000 - helper-output_mean_absolute_error: 207288.7969 - loss: 8199385088.0000 - output_loss: 10250578944.0000 - output_mean_absolute_error: 77453.0703 - val_helper-output_loss: 207175.5312 - val_helper-output_mean_absolute_error: 205885.7969 - val_loss: 8019202048.0000 - val_output_loss: 10105137152.0000 - val_output_mean_absolute_error: 75760.0078

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir=./log-boards/tb-test
# Out:
# Reusing TensorBoard on port 6006 (pid 4756), started 0:00:37 ago. (Use '!kill 4756' to kill it.)
#       <iframe id="tensorboard-frame-4cdbde56b3e333f6" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4cdbde56b3e333f6");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
