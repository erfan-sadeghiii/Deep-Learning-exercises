# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
ship = cv2.imread("Dataset\images.jpg")

# %%
plt.imshow(ship)

# %%
ship.shape
# Out:
# (191, 264, 3)

# %%
ship = ship.reshape(1,191, 264, 3)/255.0
ship.shape
# Out:
# (1, 191, 264, 3)

# %%
ship_new = tf.image.resize(ship, [299, 299])

# %%
xception = keras.applications.Xception()
# Out:
# ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\SH.Rayan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\file_utils.py:354, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     353 try:
# --> 354     urlretrieve(origin, download_target, DLProgbar())
#     355 except urllib.error.HTTPError as e:
#
# File c:\Users\SH.Rayan\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:240, in urlretrieve(url, filename, reporthook, data)
#     238 url_type, path = _splittype(url)
# --> 240 with contextlib.closing(urlopen(url, data)) as fp:
#     241     headers = fp.info()
#
# File c:\Users\SH.Rayan\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
# ...

# %%
y_prob = xception.predict(ship_new)

# %%
keras.applications.xception.decode_predictions(y_prob, top=5)
# Out:
# [[('n03673027', 'liner', 0.9248845),
#   ('n03216828', 'dock', 0.0066769323),
#   ('n03344393', 'fireboat', 0.0010699629),
#   ('n03095699', 'container_ship', 0.0007993589),
#   ('n03947888', 'pirate', 0.00057397323)]]
