# %% [markdown]
# # Regression

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("Dataset/house-price/housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data = pd.get_dummies(data, columns=['ocean_proximity'], drop_first=True,dtype=int)

# %%
y = data['median_house_value']
X = data.drop(["median_house_value"],axis=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,test_size=0.2)

# %%
sc =  StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
X_val = sc.transform(X_val)

# %% [markdown]
# ## Multi-input
# <hr>

# %%
X_train_in_1 , X_train_in_2 = X_train[:,:6],X_train[:,-4:]
X_val_in_1 , X_val_in_2 = X_val[:,:6],X_val[:,-4:]
X_test_in_1 , X_test_in_2 = X_test[:,:6],X_test[:,-4:]

# %%
input_1  = keras.layers.Input(shape=[6])
input_2  = keras.layers.Input(shape=[4])
hidden_layer1 = keras.layers.Dense(50,activation="relu")(input_1)
hidden_layer2 = keras.layers.Dense(10,activation="relu")(hidden_layer1)
concatenate_layer = keras.layers.Concatenate()([input_2,hidden_layer2])
output = keras.layers.Dense(1)(concatenate_layer)
model = keras.Model(inputs=[input_1,input_2],outputs=[output])

# %%
model.compile(loss="mean_squared_error",
              optimizer="sgd",
              metrics=["mean_absolute_error"]
              )

# %%
model.fit( (X_train_in_1,X_train_in_2) , y_train ,epochs=40 , validation_data=( (X_val_in_1,X_val_in_2) ,y_val))
# Out:
# Epoch 1/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3092888333098071860707328.0000 - mean_absolute_error: 34708619264.0000 - val_loss: 187938440203993088.0000 - val_mean_absolute_error: 430509984.0000
# Epoch 2/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 12049389599122784256.0000 - mean_absolute_error: 161920976.0000 - val_loss: 444472374591488.0000 - val_mean_absolute_error: 20753056.0000
# Epoch 3/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 347897582452324958208.0000 - mean_absolute_error: 436255328.0000 - val_loss: 773628098510848.0000 - val_mean_absolute_error: 27235704.0000
# Epoch 4/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10062763068503250436096.0000 - mean_absolute_error: 2056136960.0000 - val_loss: 5978007886578581504.0000 - val_mean_absolute_error: 2433267712.0000
# Epoch 5/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 291073534625267757088768.0000 - mean_absolute_error: 11255939072.0000 - val_loss: 8958503534014234624.0000 - val_mean_absolute_error: 2955997440.0000
# Epoch 6/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8419178734971627960795136.0000 - mean_absolute_error: 60304531456.0000 - val_loss: 8102633818135071817728.0000 - val_mean_absolute_error: 88468774912.0000
# Epoch 7/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 243528086089986208216121344.0000 - mean_absolute_error: 359431798784.0000 - val_loss: 52100590347177825402880.0000 - val_mean_absolute_error: 225934868480.0000
# Epoch 8/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7045061256877459494641074176.0000 - mean_absolute_error: 1742887714816.0000 - val_loss: 59203181290706815680512.0000 - val_mean_absolute_error: 239414378496.0000
# Epoch 9/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 203800620223304528879062876160.0000 - mean_absolute_error: 9392067969024.0000 - val_loss: 4639399945555127291609088.0000 - val_mean_absolute_error: 2132512342016.0000
# Epoch 10/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5895734771814859107801130598400.0000 - mean_absolute_error: 48739653779456.0000 - val_loss: 323427538607600664284495872.0000 - val_mean_absolute_error: 17865652568064.0000
# Epoch 11/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 170623863589346653402470234980352.0000 - mean_absolute_error: 258794479157248.0000 - val_loss: 25738443906662706223450685440.0000 - val_mean_absolute_error: 158049192902656.0000
# Epoch 12/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4935462676524329068277449925591040.0000 - mean_absolute_error: 1659346790383616.0000 - val_loss: 779142339314298052835822010368.0000 - val_mean_absolute_error: 875710746984448.0000
# Epoch 13/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 8599198299586560.0000 - val_loss: 37489353025681591124833930838016.0000 - val_mean_absolute_error: 6067940533207040.0000
# Epoch 14/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 44923154597937152.0000 - val_loss: 160774271038024980581502534287360.0000 - val_mean_absolute_error: 12571562548920320.0000
# Epoch 15/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 191747560799469568.0000 - val_loss: 45452889825303707703107989324955648.0000 - val_mean_absolute_error: 208197216823672832.0000
# Epoch 16/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 1066344859524136960.0000 - val_loss: inf - val_mean_absolute_error: 1725805683024068608.0000
# Epoch 17/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 6155193085883056128.0000 - val_loss: inf - val_mean_absolute_error: 5461760789058682880.0000
# Epoch 18/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 41452450384271376384.0000 - val_loss: inf - val_mean_absolute_error: 10599791270039650304.0000
# Epoch 19/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 195088406402062876672.0000 - val_loss: inf - val_mean_absolute_error: 86985355544986910720.0000
# Epoch 20/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 1185622563713649213440.0000 - val_loss: inf - val_mean_absolute_error: 295622718280691613696.0000
# Epoch 21/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 5792720117808188358656.0000 - val_loss: inf - val_mean_absolute_error: 1541645202843703967744.0000
# Epoch 22/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 27802744867790574845952.0000 - val_loss: inf - val_mean_absolute_error: 21981567629836939165696.0000
# Epoch 23/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 139065563022463722323968.0000 - val_loss: inf - val_mean_absolute_error: 180604162904744557281280.0000
# Epoch 24/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 986268790786154345529344.0000 - val_loss: inf - val_mean_absolute_error: 78299114747102196924416.0000
# Epoch 25/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 4827564517327120814309376.0000 - val_loss: inf - val_mean_absolute_error: 3415116923268758763470848.0000
# Epoch 26/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 23862830343430164296237056.0000 - val_loss: inf - val_mean_absolute_error: 36965245981865833387786240.0000
# Epoch 27/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 136021199498169889780137984.0000 - val_loss: inf - val_mean_absolute_error: 115311694786030792869937152.0000
# Epoch 28/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 772034534925441756158754816.0000 - val_loss: inf - val_mean_absolute_error: 57537267110423573009793024.0000
# Epoch 29/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 3963392168961413525243166720.0000 - val_loss: inf - val_mean_absolute_error: 419325520218950087697498112.0000
# Epoch 30/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 18582237032244426759060062208.0000 - val_loss: inf - val_mean_absolute_error: 33011256634867623684869193728.0000
# Epoch 31/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 121639839788979244389942427648.0000 - val_loss: inf - val_mean_absolute_error: 72320294267855586314239868928.0000
# Epoch 32/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 587088341264608725725695967232.0000 - val_loss: inf - val_mean_absolute_error: 256389006713336486850266660864.0000
# Epoch 33/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 3331587694608030541727353798656.0000 - val_loss: inf - val_mean_absolute_error: 1038104299071627168662899654656.0000
# Epoch 34/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 18621888335194176906400408535040.0000 - val_loss: inf - val_mean_absolute_error: 1932757913734964794941104979968.0000
# Epoch 35/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 104860368683314006543601357553664.0000 - val_loss: inf - val_mean_absolute_error: 16729301666403459172476968239104.0000
# Epoch 36/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 479789349480864297177859749838848.0000 - val_loss: inf - val_mean_absolute_error: 598927306179145098781342203641856.0000
# Epoch 37/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 2688895515980694147150828001034240.0000 - val_loss: inf - val_mean_absolute_error: 175220741154288660878573384499200.0000
# Epoch 38/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: inf - mean_absolute_error: 16585317769546392942904590479654912.0000 - val_loss: inf - val_mean_absolute_error: 4759535613206375642615779409526784.0000
# Epoch 39/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 40/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan

# %%
print(f"X_train_in_1 shape: {X_train_in_1.shape}")
print(f"X_train_in_2 shape: {X_train_in_2.shape}")  # You're using X_test_in_2 here - is this a typo?
print(f"y_train shape: {y_train.shape}")
# Out:
# X_train_in_1 shape: (13209, 6)
# X_train_in_2 shape: (13209, 4)
# y_train shape: (13209,)
