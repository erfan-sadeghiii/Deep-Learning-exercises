# %% [markdown]
# # Regression

# %% [markdown]
# `note` : *this notebook focus is exploring tensorflow and keras ,**not fitting the best model***

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("Dataset/house-price/housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data = pd.get_dummies(data, columns=['ocean_proximity'], drop_first=True,dtype=int)

# %%
y = data['median_house_value']
X = data.drop(["median_house_value"],axis=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,test_size=0.2)

# %%
sc =  StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
X_val = sc.transform(X_val)

# %%
model =  keras.models.Sequential([
    keras.layers.Dense(50,activation="relu"),
    keras.layers.Dense(10,activation="relu"),
    keras.layers.Dense(1)
])

# %%
model.compile(loss="mean_squared_error",
              optimizer="sgd",
              metrics=["mean_absolute_error"]
              )

# %%
model.fit(X_train,y_train,epochs=40,validation_data=(X_val,y_val))
# Out:
# Epoch 1/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 140450000424402944.0000 - mean_absolute_error: 31263520.0000 - val_loss: 14449002496.0000 - val_mean_absolute_error: 88476.4609
# Epoch 2/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13359520768.0000 - mean_absolute_error: 90333.1562 - val_loss: 13274663936.0000 - val_mean_absolute_error: 90888.5078
# Epoch 3/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13303237632.0000 - mean_absolute_error: 90894.8203 - val_loss: 13275095040.0000 - val_mean_absolute_error: 90834.3281
# Epoch 4/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13301129216.0000 - mean_absolute_error: 90867.7422 - val_loss: 13274718208.0000 - val_mean_absolute_error: 90880.4375
# Epoch 5/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 13297516544.0000 - mean_absolute_error: 90867.4141 - val_loss: 13274500096.0000 - val_mean_absolute_error: 90918.6953
# Epoch 6/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 13296396288.0000 - mean_absolute_error: 90966.0625 - val_loss: 13290317824.0000 - val_mean_absolute_error: 90311.7344
# Epoch 7/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13300494336.0000 - mean_absolute_error: 90798.9688 - val_loss: 13275169792.0000 - val_mean_absolute_error: 90827.3125
# Epoch 8/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13298689024.0000 - mean_absolute_error: 90948.9766 - val_loss: 13292680192.0000 - val_mean_absolute_error: 90266.3750
# Epoch 9/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13303176192.0000 - mean_absolute_error: 90865.0547 - val_loss: 13287521280.0000 - val_mean_absolute_error: 90370.5859
# Epoch 10/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 13297817600.0000 - mean_absolute_error: 90806.2734 - val_loss: 13274507264.0000 - val_mean_absolute_error: 90917.4375
# Epoch 11/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13302863872.0000 - mean_absolute_error: 90911.8984 - val_loss: 13277253632.0000 - val_mean_absolute_error: 90688.7969
# Epoch 12/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13300734976.0000 - mean_absolute_error: 90913.9844 - val_loss: 13282255872.0000 - val_mean_absolute_error: 90503.5703
# Epoch 13/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13301109760.0000 - mean_absolute_error: 90810.5781 - val_loss: 13274823680.0000 - val_mean_absolute_error: 91115.5078
# Epoch 14/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13300210688.0000 - mean_absolute_error: 90884.2812 - val_loss: 13274381312.0000 - val_mean_absolute_error: 91023.5000
# Epoch 15/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13300660224.0000 - mean_absolute_error: 90900.3125 - val_loss: 13274427392.0000 - val_mean_absolute_error: 90938.1016
# Epoch 16/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13303013376.0000 - mean_absolute_error: 90938.1797 - val_loss: 13278625792.0000 - val_mean_absolute_error: 90627.2422
# Epoch 17/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13300379648.0000 - mean_absolute_error: 90897.9375 - val_loss: 13288780800.0000 - val_mean_absolute_error: 90343.3984
# Epoch 18/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13299833856.0000 - mean_absolute_error: 90804.0547 - val_loss: 13274365952.0000 - val_mean_absolute_error: 91014.4844
# Epoch 19/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13298196480.0000 - mean_absolute_error: 90865.9141 - val_loss: 13274724352.0000 - val_mean_absolute_error: 90878.9219
# Epoch 20/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13302451200.0000 - mean_absolute_error: 90896.8203 - val_loss: 13276684288.0000 - val_mean_absolute_error: 90718.8672
# Epoch 21/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 13300462592.0000 - mean_absolute_error: 90891.9766 - val_loss: 13278981120.0000 - val_mean_absolute_error: 90613.0547
# Epoch 22/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13301796864.0000 - mean_absolute_error: 90837.8281 - val_loss: 13274534912.0000 - val_mean_absolute_error: 90911.8750
# Epoch 23/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 13302030336.0000 - mean_absolute_error: 90823.0781 - val_loss: 13275700224.0000 - val_mean_absolute_error: 91203.6719
# Epoch 24/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13301429248.0000 - mean_absolute_error: 90957.3203 - val_loss: 13277659136.0000 - val_mean_absolute_error: 90669.4062
# Epoch 25/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 13302981632.0000 - mean_absolute_error: 90887.7031 - val_loss: 13278316544.0000 - val_mean_absolute_error: 90640.1797
# Epoch 26/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 13300539392.0000 - mean_absolute_error: 90873.0625 - val_loss: 13278049280.0000 - val_mean_absolute_error: 90651.6797
# Epoch 27/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 13299777536.0000 - mean_absolute_error: 90820.1172 - val_loss: 13274449920.0000 - val_mean_absolute_error: 91048.0391
# Epoch 28/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 13302589440.0000 - mean_absolute_error: 90976.4297 - val_loss: 13286063104.0000 - val_mean_absolute_error: 90403.9453
# Epoch 29/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13301134336.0000 - mean_absolute_error: 90873.7500 - val_loss: 13288691712.0000 - val_mean_absolute_error: 90345.1719
# Epoch 30/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13302069248.0000 - mean_absolute_error: 90816.8672 - val_loss: 13275021312.0000 - val_mean_absolute_error: 90842.8047
# Epoch 31/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13296601088.0000 - mean_absolute_error: 90986.4766 - val_loss: 13318505472.0000 - val_mean_absolute_error: 89903.9453
# Epoch 32/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13302293504.0000 - mean_absolute_error: 90735.1641 - val_loss: 13274409984.0000 - val_mean_absolute_error: 90942.8750
# Epoch 33/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13303343104.0000 - mean_absolute_error: 90937.2109 - val_loss: 13279838208.0000 - val_mean_absolute_error: 90581.1875
# Epoch 34/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13300251648.0000 - mean_absolute_error: 90861.7734 - val_loss: 13279064064.0000 - val_mean_absolute_error: 90609.9688
# Epoch 35/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13299672064.0000 - mean_absolute_error: 90877.5703 - val_loss: 13282266112.0000 - val_mean_absolute_error: 90503.1406
# Epoch 36/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13303032832.0000 - mean_absolute_error: 90840.1406 - val_loss: 13276325888.0000 - val_mean_absolute_error: 90740.0703
# Epoch 37/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 13298347008.0000 - mean_absolute_error: 90905.7344 - val_loss: 13282719744.0000 - val_mean_absolute_error: 90490.0703
# Epoch 38/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 13300943872.0000 - mean_absolute_error: 90794.2891 - val_loss: 13275125760.0000 - val_mean_absolute_error: 91151.0156
# Epoch 39/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13301305344.0000 - mean_absolute_error: 90868.9375 - val_loss: 13276944384.0000 - val_mean_absolute_error: 91288.7422
# Epoch 40/40
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13302109184.0000 - mean_absolute_error: 90911.5312 - val_loss: 13274475520.0000 - val_mean_absolute_error: 91054.8594

# %%
model.evaluate(X_test,y_test)
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 13409187840.0000 - mean_absolute_error: 92337.1094
# [13409187840.0, 92337.109375]
