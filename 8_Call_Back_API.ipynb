# %% [markdown]
# # Regression

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("Dataset/house-price/housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data = pd.get_dummies(data, columns=['ocean_proximity'], drop_first=True,dtype=int)

# %%
y = data['median_house_value']
X = data.drop(["median_house_value"],axis=1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,test_size=0.2)

# %%
sc =  StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
X_val = sc.transform(X_val)

# %% [markdown]
# ## Call-Back API
# <hr>

# %%
model_checkpoint_cb = keras.callbacks.ModelCheckpoint("models/model_reg_cb_best_epoch.h5",save_best_only=True)


early_stop_cb = keras.callbacks.EarlyStopping(patience=5,restore_best_weights=True)

# %% [markdown]
# Costume Callback

# %%
class MyCallback(keras.callbacks.Callback):
    def on_train_end (self,logs=None):
        print("")
    def on_epoch_end(self,epoch,logs):
        print(logs["val_loss"])

# %%
mycb = MyCallback()

# %%
model_d.fit( (X_train_in_1,X_train_in_2) ,
             (y_train,y_train) , 
             epochs=5 ,
             validation_data=( (X_val_in_1,X_val_in_2) ,(y_val,y_val)),
             callbacks=[model_checkpoint_cb , early_stop_cb]
             
             )
# Out:
# Epoch 1/5
# 391/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - helper-output_loss: 207042.3851 - helper-output_mean_absolute_error: 207042.3851 - loss: inf - output_loss: inf - output_mean_absolute_error: 52279293766976947122694476791808.0000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - helper-output_loss: 207095.2031 - helper-output_mean_absolute_error: 207084.7500 - loss: inf - output_loss: inf - output_mean_absolute_error: 106900426168210414817401330728960.0000 - val_helper-output_loss: 206963.0781 - val_helper-output_mean_absolute_error: 207518.4062 - val_loss: inf - val_output_loss: inf - val_output_mean_absolute_error: 2507854367617947904901014840410112.0000
# Epoch 2/5
# ...
